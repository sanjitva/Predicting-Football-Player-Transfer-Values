# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))
# Out:
# <style>.container { width:85% !important; }</style>

# %%
import numpy as np
import pandas as pd
from functools import reduce

# %%
england_std21 = pd.read_excel('data/league_data/england/21/england_std.xlsx')

france_std21 = pd.read_excel('data/league_data/france/21/france_std.xlsx')
france_std21.columns = england_std21.columns

germany_std21 = pd.read_excel('data/league_data/germany/21/germany_std.xlsx')
germany_std21.columns = england_std21.columns

italy_std21 = pd.read_excel('data/league_data/italy/21/italy_std.xlsx')
italy_std21.columns = england_std21.columns

spain_std21 = pd.read_excel('data/league_data/spain/21/spain_std.xlsx')
spain_std21.columns = england_std21.columns



s21_std = pd.concat([england_std21,france_std21,germany_std21,italy_std21,spain_std21])


england_shooting21 = pd.read_excel('data/league_data/england/21/england_shooting.xlsx')

# %%
def clean_std(dataframe):

    original = []
    duplicate = []

    for a in dataframe['Player']:
        if a not in original:
            original.append(a)
        else:
            duplicate.append(a)
    
    mid_season_transfers = pd.DataFrame(columns = dataframe.columns)

    for a in duplicate:
        player = dataframe[dataframe['Player']==a]
        mid_season_transfers = mid_season_transfers.append(dataframe[dataframe['Player']==a])
    
    
    first = mid_season_transfers.iloc[::2]
    second = mid_season_transfers.iloc[1::2]
    
    midseason = []

    for a in list(range(len(first))):

        double_club_combined = pd.Series([first.iloc[a]['Player'],
                           [first.iloc[a]['Squad'],second.iloc[a]['Squad']],
                           first.iloc[a]['MP']+second.iloc[a]['MP'],
                            first.iloc[a]['Starts']+second.iloc[a]['Starts'],
                            first.iloc[a]['Min']+second.iloc[a]['Min'],
                           (first.iloc[a]['Min']+second.iloc[a]['Min'])/90,
                           first.iloc[a]['Gls']+second.iloc[a]['Gls'],
                           first.iloc[a]['Ast']+second.iloc[a]['Ast'],
                           first.iloc[a]['Non-Penalty Goals']+second.iloc[a]['Non-Penalty Goals'],
                           first.iloc[a]['Penalties Scored']+second.iloc[a]['Penalties Scored'],
                           first.iloc[a]['Penalties Attempted']+second.iloc[a]['Penalties Attempted'],
                           first.iloc[a]['Yellow Cards']+second.iloc[a]['Yellow Cards'],
                           first.iloc[a]['Red Cards']+second.iloc[a]['Red Cards'],
                           (first.iloc[a]['Gls']+second.iloc[a]['Gls'])/90,
                           (first.iloc[a]['Ast']+second.iloc[a]['Ast'])/90,
                           ((first.iloc[a]['Gls']+second.iloc[a]['Gls'])+(first.iloc[a]['Ast']+second.iloc[a]['Ast']))/90,
                           ((first.iloc[a]['Gls']+second.iloc[a]['Gls'])-(first.iloc[a]['Penalties Scored']+second.iloc[a]['Penalties Scored']))/90,
                           ((first.iloc[a]['Gls']+second.iloc[a]['Gls'])+(first.iloc[a]['Ast']+second.iloc[a]['Ast'])-(first.iloc[a]['Penalties Scored']+second.iloc[a]['Penalties Scored']))/90,
                           first.iloc[a]['xG']+second.iloc[a]['xG'],
                           first.iloc[a]['Non-Penalty xG']+second.iloc[a]['Non-Penalty xG'],
                           first.iloc[a]['xA']+second.iloc[a]['xA'],
                           first.iloc[a]['Non-penalty xG+ xA']+second.iloc[a]['Non-penalty xG+ xA'],
                           (first.iloc[a]['xG']+second.iloc[a]['xG'])/90,
                           (first.iloc[a]['xA']+second.iloc[a]['xA'])/90,
                           ((first.iloc[a]['xG']+second.iloc[a]['xG'])+(first.iloc[a]['xA']+second.iloc[a]['xA']))/90,
                           (first.iloc[a]['Non-Penalty xG']+second.iloc[a]['Non-Penalty xG'])/90,
                           (first.iloc[a]['Non-penalty xG+ xA']+second.iloc[a]['Non-penalty xG+ xA'])/90])

        midseason.append(double_club_combined)

    transferred_players = pd.DataFrame(midseason)
    transferred_players.columns = ['Player','Squad','MP','Starts','Min',
                                   'Total Mins/90','Gls','Ast','Non-Penalty Goals',
                                    'Penalties Scored','Penalties Attempted','Yellow Cards',
                                   'Red Cards','Gls/90','Ast/90','(G+A)/90','Non-Penalty Goals/90',
                                   '(Gls+Ast-Scored Penalties)/90','xG','Non-Penalty xG','xA',
                                    'Non-penalty xG+ xA','xG/90','xA/90','(xG+xA)/90',
                                     'Non-Penalty xG/90','(Non-Penalty xG+xA)/90']
    
    final_df = pd.concat([dataframe, mid_season_transfers, mid_season_transfers]).drop_duplicates(keep=False)
    final_df = pd.concat([final_df,transferred_players])
    return final_df

# %%
clean_std(s21_std).tail(40)
# Out:
#                  Player                          Squad  MP Starts   Min  \
# 35     Mickaël Cuisance     [Marseille, Bayern Munich]  24     11  1042
# 36      Joel Pohjanpalo     [Union Berlin, Leverkusen]  20     10   857
# 37         Maxime Lopez          [Marseille, Sassuolo]  33     24  1998
# 38       Adama Soumaoro               [Lille, Bologna]  23     20  1900
# 39        Fikayo Tomori               [Chelsea, Milan]  18     16  1511
# 40      Kevin Strootman             [Marseille, Genoa]  29     19  1547
# 41        Kevin Lasagna       [Hellas Verona, Udinese]  36     26  2370
# 42          Mattia Bani                 [Parma, Genoa]  26     24  2066
# 43       Soualiho Meïté                [Torino, Milan]  30     15  1508
# 44           Pol Lirola        [Marseille, Fiorentina]  31     21  2051
# 45    Samuel Di Carmine       [Hellas Verona, Crotone]  22     12   975
# 46      Stefano Sturaro         [Genoa, Hellas Verona]  16     10   868
# 47   Rolando Mandragora              [Torino, Udinese]  27     20  1923
# 48    Alessandro Deiola             [Cagliari, Spezia]  24     11   975
# 49           Adam Ounas            [Crotone, Cagliari]  22     18  1507
# 50  Federico Ceccherini    [Hellas Verona, Fiorentina]  28     26  2008
# 51      Federico Chiesa         [Juventus, Fiorentina]  33     31  2450
# 52       Matteo Darmian                 [Inter, Parma]  29     16  1368
# 53      Patrick Cutrone           [Wolves, Fiorentina]  13      0   221
# 54        Fabio Depaoli          [Benevento, Atalanta]  20     17  1311
# 55        Alfred Duncan         [Cagliari, Fiorentina]  23     14  1230
# 56                Nacho      [Real Madrid, Valladolid]  47     43  3813
# 57         Aarón Martín         [Mainz 05, Celta Vigo]  24     20  1802
# 58          Lucas Olaza       [Celta Vigo, Valladolid]  32     32  2875
# 59         Johan Mojica              [Atalanta, Elche]  28     17  1503
# 60     Antonio Sanabria                [Torino, Betis]  30     22  1910
# 61           Papu Gómez            [Atalanta, Sevilla]  28     20  1580
# 62         Willian José        [Wolves, Real Sociedad]  30     20  1799
# 63                 Jota           [Alavés, Valladolid]  40     25  2066
# 64              Rodrigo          [Leeds United, Betis]  41     19  1825
# 65          Raúl García    [Athletic Club, Valladolid]  42     26  2247
# 66         Okay Yokuşlu        [West Brom, Celta Vigo]  28     18  1779
# 67        Javi Martínez       [Bayern Munich, Osasuna]  32     10   926
# 68   Geoffrey Kondogbia    [Atlético Madrid, Valencia]  30      9  1051
# 69        Takefusa Kubo           [Getafe, Villarreal]  31     10  1104
# 70      Martin Ødegaard         [Arsenal, Real Madrid]  21     12  1100
# 71        Thomas Partey     [Arsenal, Atlético Madrid]  27     20  1734
# 72      Christian Oliva           [Cagliari, Valencia]  19      4   586
# 73           Luka Jović  [Eint Frankfurt, Real Madrid]  22     10  1043
# 74     Carlos Fernández       [Real Sociedad, Sevilla]  16      6   533
#
#     Total Mins/90 Gls Ast Non-Penalty Goals Penalties Scored  ...  \
# 35      11.577778   2   1                 2                0  ...
# 36       9.522222   6   0                 6                0  ...
# 37      22.200000   2   0                 2                0  ...
# 38      21.111111   1   0                 1                0  ...
# 39      16.788889   1   0                 1                0  ...
# 40      17.188889   0   4                 0                0  ...
# 41      26.333333   4   1                 4                0  ...
# 42      22.955556   0   0                 0                0  ...
# 43      16.755556   1   1                 1                0  ...
# 44      22.788889   2   3                 2                0  ...
# 45      10.833333   0   0                 0                0  ...
# 46       9.644444   1   0                 1                0  ...
# 47      21.366667   3   1                 3                0  ...
# 48      10.833333   0   0                 0                0  ...
# 49      16.744444   4   4                 4                0  ...
# 50      22.311111   0   0                 0                0  ...
# 51      27.222222   9   9                 9                0  ...
# 52      15.200000   3   3                 3                0  ...
# 53       2.455556   0   0                 0                0  ...
# 54      14.566667   0   0                 0                0  ...
# 55      13.666667   0   1                 0                0  ...
# 56      42.366667   1   1                 1                0  ...
# 57      20.022222   0   3                 0                0  ...
# 58      31.944444   1   3                 1                0  ...
# 59      16.700000   0   0                 0                0  ...
# 60      21.222222   8   1                 8                0  ...
# 61      17.555556   7   3                 7                0  ...
# 62      19.988889   4   1                 4                0  ...
# 63      22.955556   1   2                 1                0  ...
# 64      20.277778   7   2                 7                0  ...
# 65      24.966667   6   1                 4                2  ...
# 66      19.766667   0   1                 0                0  ...
# 67      10.288889   1   1                 1                0  ...
# 68      11.677778   0   0                 0                0  ...
# 69      12.266667   1   1                 1                0  ...
# 70      12.222222   1   2                 1                0  ...
# 71      19.266667   0   2                 0                0  ...
# 72       6.511111   0   3                 0                0  ...
# 73      11.588889   4   1                 4                0  ...
# 74       5.922222   1   2                 1                0  ...
#
#    (Gls+Ast-Scored Penalties)/90    xG Non-Penalty xG   xA  \
# 35                      0.033333   0.9            0.9  0.7
# 36                      0.066667   6.9            6.9  1.4
# 37                      0.022222   1.6            1.6  1.2
# 38                      0.011111   1.3            1.3  0.1
# 39                      0.011111   0.4            0.4  0.0
# 40                      0.044444   0.5            0.5  2.7
# 41                      0.055556  10.7           10.7  1.7
# 42                      0.000000   1.1            1.1  0.4
# 43                      0.022222   1.0            1.0  0.7
# 44                      0.055556   1.9            1.9  2.5
# 45                      0.000000   2.0            2.0  0.1
# 46                      0.011111   0.4            0.4  0.2
# 47                      0.044444   2.9            2.9  0.8
# 48                      0.000000   0.4            0.4  0.8
# 49                      0.088889   3.2            3.2  4.5
# 50                      0.000000   0.9            0.9  0.2
# 51                      0.200000   6.7            6.7  7.3
# 52                      0.066667   1.2            1.2  1.5
# 53                      0.000000   0.4            0.4  0.0
# 54                      0.000000   0.2            0.2  0.5
# 55                      0.011111   0.2            0.2  1.1
# 56                      0.022222   1.8            1.8  2.0
# 57                      0.033333   0.2            0.2  1.6
# 58                      0.044444   1.0            1.0  3.2
# 59                      0.000000   0.2            0.2  1.1
# 60                      0.100000   7.3            7.3  1.2
# 61                      0.111111   3.4            3.4  2.5
# 62                      0.055556   6.2            5.4  1.5
# 63                      0.033333   NaN            NaN  NaN
# 64                      0.100000   6.5            6.5  2.9
# 65                      0.055556   6.5            4.2  1.5
# 66                      0.011111   1.3            1.3  0.9
# 67                      0.022222   0.9            0.9  0.7
# 68                      0.000000   0.3            0.3  0.3
# 69                      0.022222   2.3            2.3  1.3
# 70                      0.033333   1.2            1.2  2.5
# 71                      0.022222   1.4            1.4  1.0
# 72                      0.033333   0.0            0.0  0.3
# 73                      0.055556   3.8            3.8  0.7
# 74                      0.033333   1.2            1.2  0.7
#
#     Non-penalty xG+ xA     xG/90     xA/90  (xG+xA)/90  Non-Penalty xG/90  \
# 35                 1.6  0.010000  0.007778    0.017778           0.010000
# 36                 8.2  0.076667  0.015556    0.092222           0.076667
# 37                 2.8  0.017778  0.013333    0.031111           0.017778
# 38                 1.4  0.014444  0.001111    0.015556           0.014444
# 39                 0.4  0.004444  0.000000    0.004444           0.004444
# 40                 3.1  0.005556  0.030000    0.035556           0.005556
# 41                12.5  0.118889  0.018889    0.137778           0.118889
# 42                 1.5  0.012222  0.004444    0.016667           0.012222
# 43                 1.7  0.011111  0.007778    0.018889           0.011111
# 44                 4.4  0.021111  0.027778    0.048889           0.021111
# 45                 2.1  0.022222  0.001111    0.023333           0.022222
# 46                 0.6  0.004444  0.002222    0.006667           0.004444
# 47                 3.7  0.032222  0.008889    0.041111           0.032222
# 48                 1.1  0.004444  0.008889    0.013333           0.004444
# 49                 7.7  0.035556  0.050000    0.085556           0.035556
# 50                 1.2  0.010000  0.002222    0.012222           0.010000
# 51                14.1  0.074444  0.081111    0.155556           0.074444
# 52                 2.7  0.013333  0.016667    0.030000           0.013333
# 53                 0.4  0.004444  0.000000    0.004444           0.004444
# 54                 0.7  0.002222  0.005556    0.007778           0.002222
# 55                 1.4  0.002222  0.012222    0.014444           0.002222
# 56                 3.8  0.020000  0.022222    0.042222           0.020000
# 57                 1.8  0.002222  0.017778    0.020000           0.002222
# 58                 4.1  0.011111  0.035556    0.046667           0.011111
# 59                 1.3  0.002222  0.012222    0.014444           0.002222
# 60                 8.5  0.081111  0.013333    0.094444           0.081111
# 61                 6.0  0.037778  0.027778    0.065556           0.037778
# 62                 6.8  0.068889  0.016667    0.085556           0.060000
# 63                 NaN       NaN       NaN         NaN                NaN
# 64                 9.3  0.072222  0.032222    0.104444           0.072222
# 65                 5.8  0.072222  0.016667    0.088889           0.046667
# 66                 2.2  0.014444  0.010000    0.024444           0.014444
# 67                 1.5  0.010000  0.007778    0.017778           0.010000
# 68                 0.5  0.003333  0.003333    0.006667           0.003333
# 69                 3.6  0.025556  0.014444    0.040000           0.025556
# 70                 3.7  0.013333  0.027778    0.041111           0.013333
# 71                 2.4  0.015556  0.011111    0.026667           0.015556
# 72                 0.3  0.000000  0.003333    0.003333           0.000000
# 73                 4.6  0.042222  0.007778    0.050000           0.042222
# 74                 2.0  0.013333  0.007778    0.021111           0.013333
#
#     (Non-Penalty xG+xA)/90
# 35                0.017778
# 36                0.091111
# 37                0.031111
# 38                0.015556
# 39                0.004444
# 40                0.034444
# 41                0.138889
# 42                0.016667
# 43                0.018889
# 44                0.048889
# 45                0.023333
# 46                0.006667
# 47                0.041111
# 48                0.012222
# 49                0.085556
# 50                0.013333
# 51                0.156667
# 52                0.030000
# 53                0.004444
# 54                0.007778
# 55                0.015556
# 56                0.042222
# 57                0.020000
# 58                0.045556
# 59                0.014444
# 60                0.094444
# 61                0.066667
# 62                0.075556
# 63                     NaN
# 64                0.103333
# 65                0.064444
# 66                0.024444
# 67                0.016667
# 68                0.005556
# 69                0.040000
# 70                0.041111
# 71                0.026667
# 72                0.003333
# 73                0.051111
# 74                0.022222
#
# [40 rows x 27 columns]

# %%
s21_std
# Out:
#                  Player           Squad  MP  Starts   Min  Total Mins/90  Gls  \
# 0       Pierre Højbjerg       Tottenham  38      38  3420           38.0    2
# 1           Hugo Lloris       Tottenham  38      38  3420           38.0    0
# 2     Emiliano Martínez     Aston Villa  38      38  3420           38.0    0
# 3        Aaron Ramsdale   Sheffield Utd  38      38  3420           38.0    0
# 4     Kasper Schmeichel  Leicester City  38      38  3420           38.0    0
# ..                  ...             ...  ..     ...   ...            ...  ...
# 494          Alex Baena      Villarreal   6       2   137            1.5    0
# 495  Miguel Ángel Rubio      Valladolid   2       1   135            1.5    0
# 496      Sergio Arribas     Real Madrid   8       0   135            1.5    0
# 497              Marvin     Real Madrid   4       2   133            1.5    0
# 498       Gabriel Veiga      Celta Vigo   6       1   118            1.3    0
#
#      Ast  Non-Penalty Goals  Penalties Scored  ...  \
# 0      4                  2                 0  ...
# 1      0                  0                 0  ...
# 2      0                  0                 0  ...
# 3      0                  0                 0  ...
# 4      0                  0                 0  ...
# ..   ...                ...               ...  ...
# 494    0                  0                 0  ...
# 495    0                  0                 0  ...
# 496    0                  0                 0  ...
# 497    1                  0                 0  ...
# 498    0                  0                 0  ...
#
#      (Gls+Ast-Scored Penalties)/90   xG  Non-Penalty xG   xA  \
# 0                             0.16  1.1             1.1  1.9
# 1                             0.00  0.0             0.0  0.0
# 2                             0.00  0.0             0.0  0.2
# 3                             0.00  0.0             0.0  0.2
# 4                             0.00  0.0             0.0  0.0
# ..                             ...  ...             ...  ...
# 494                           0.00  0.1             0.1  0.1
# 495                           0.00  0.0             0.0  0.0
# 496                           0.00  0.0             0.0  0.0
# 497                           0.68  0.2             0.2  0.2
# 498                           0.00  0.0             0.0  0.0
#
#      Non-penalty xG+ xA  xG/90  xA/90  (xG+xA)/90  Non-Penalty xG/90  \
# 0                   3.0   0.03   0.05        0.08               0.03
# 1                   0.0   0.00   0.00        0.00               0.00
# 2                   0.2   0.00   0.01        0.01               0.00
# 3                   0.2   0.00   0.00        0.00               0.00
# 4                   0.0   0.00   0.00        0.00               0.00
# ..                  ...    ...    ...         ...                ...
# 494                 0.1   0.05   0.05        0.09               0.05
# 495                 0.0   0.02   0.00        0.02               0.02
# 496                 0.1   0.02   0.03        0.05               0.02
# 497                 0.4   0.11   0.13        0.24               0.11
# 498                 0.0   0.00   0.03        0.03               0.00
#
#      (Non-Penalty xG+xA)/90
# 0                      0.08
# 1                      0.00
# 2                      0.01
# 3                      0.00
# 4                      0.00
# ..                      ...
# 494                    0.09
# 495                    0.02
# 496                    0.05
# 497                    0.24
# 498                    0.03
#
# [2495 rows x 27 columns]

# %%
def check_dupes(dataframe):

    original = []
    duplicate = []

    for a in dataframe['Player']:
        if a not in original:
            original.append(a)
        else:
            duplicate.append(a)

    mid_season_transfers = pd.DataFrame(columns = dataframe.columns)

    for a in duplicate:
        player = dataframe[dataframe['Player']==a]
        mid_season_transfers = mid_season_transfers.append(dataframe[dataframe['Player']==a])
    
    return mid_season_transfers

# %%
check_dupes(england_shooting21)
# Out:
#       Rk                  Player   Nation    Pos          Squad Age  Born  \
# 285  286  Ainsley Maitland-Niles  eng ENG     MF      West Brom  22  1997
# 393  394  Ainsley Maitland-Niles  eng ENG     DF        Arsenal  22  1997
# 356  357         Takumi Minamino   jp JPN  MF,FW    Southampton  25  1995
# 413  414         Takumi Minamino   jp JPN  MF,FW      Liverpool  25  1995
# 314  315             Mathew Ryan   au AUS     GK       Brighton  28  1992
# 427  428             Mathew Ryan   au AUS     GK        Arsenal  28  1992
# 315  316             Joe Willock  eng ENG     MF  Newcastle Utd  20  1999
# 435  436             Joe Willock  eng ENG     MF        Arsenal  20  1999
# 188  189      Ruben Loftus-Cheek  eng ENG  MF,FW         Fulham  24  1996
# 482  483      Ruben Loftus-Cheek  eng ENG     FW        Chelsea  24  1996
# 232  233            Ross Barkley  eng ENG     MF    Aston Villa  26  1993
# 485  486            Ross Barkley  eng ENG     MF        Chelsea  26  1993
#
#      90s▼ Gls Total Shots  ... Goals/Shots on Target  Avg Shot Distance (yds)  \
# 285  13.7   0          10  ...                  0.00                     22.3
# 393   5.4   0           2  ...                  0.00                     20.5
# 356   7.9   2          13  ...                  0.50                     17.5
# 413   3.3   1           7  ...                  0.33                     16.4
# 314  11.0   0           0  ...                   NaN                      NaN
# 427   3.0   0           0  ...                   NaN                      NaN
# 315  10.9   8          17  ...                  0.67                     13.2
# 435   2.6   0           4  ...                   NaN                     10.3
# 188  21.2   1          37  ...                  0.13                     15.1
# 482   0.7   0           0  ...                   NaN                      NaN
# 232  17.0   3          38  ...                  0.27                     18.4
# 485   0.5   0           1  ...                  0.00                     28.0
#
#      Freekick Shots  Penalties Scored  Penalties Attempted   xG  \
# 285               0                 0                    0  0.7
# 393               0                 0                    0  0.1
# 356               0                 0                    0  1.2
# 413               0                 0                    0  0.7
# 314               0                 0                    0  0.0
# 427               0                 0                    0  0.0
# 315               0                 0                    1  3.6
# 435               0                 0                    0  0.4
# 188               0                 0                    0  3.1
# 482               0                 0                    0  0.0
# 232               2                 0                    0  3.2
# 485               0                 0                    0  0.0
#
#      Non-Penalty xG Non-Penalty xG/Shots Goals Scored minus xG  \
# 285             0.7                 0.07                  -0.7
# 393             0.1                 0.06                  -0.1
# 356             1.2                 0.09                   0.8
# 413             0.7                 0.09                   0.3
# 314             0.0                  NaN                   0.0
# 427             0.0                  NaN                   0.0
# 315             2.6                 0.16                   4.4
# 435             0.4                 0.11                  -0.4
# 188             3.1                 0.08                  -2.1
# 482             0.0                  NaN                   0.0
# 232             3.2                 0.08                  -0.2
# 485             0.0                 0.03                   0.0
#
#     Non-Penalty Goals Scored minus Non-Penalty xG
# 285                                          -0.7
# 393                                          -0.1
# 356                                           0.8
# 413                                           0.3
# 314                                           0.0
# 427                                           0.0
# 315                                           5.4
# 435                                          -0.4
# 188                                          -2.1
# 482                                           0.0
# 232                                          -0.2
# 485                                           0.0
#
# [12 rows x 25 columns]
